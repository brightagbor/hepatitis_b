# %% [markdown]
# # Machine Learning Modeling Using SMOTE and Bootstrapping

# %%
# %%capture
# %matplotlib inline
import pycaret

from sklearn.utils import resample
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from Exploratory_Data_Analysis import *
from pycaret.classification import *

# %% [markdown]
# ### The Dataset

# %%
X = ds.drop("class", axis=1)
y = ds["class"]

# %% [markdown]
# ### Fit SMOTE to training data

# %%
### Instantiating SMOTE
sm = SMOTE(random_state=42)

### Fit SMOTE to training data
X_resampled, y_resampled = sm.fit_resample(X, y)

# %% [markdown]
# ### Printing class disribution of original and resampled data

# %%
print("Class Distribution before Resampleing: ", y.value_counts())

print("\nClass Distribution afer Resampling", y_resampled.value_counts())
# Out:
# Class Distribution before Resampleing:  class
# 1    123
# 0     32
# Name: count, dtype: int64
#
# Class Distribution afer Resampling class
# 1    123
# 0    123
# Name: count, dtype: int64

# %% [markdown]
# ####  Using bootstrapping to further increase dataset size

# %%
X_resampled, y_resampled = resample(X_resampled, y_resampled, n_samples=10000, random_state=42)

# %%
y_resampled.value_counts()
# Out:
# class
# 1    5047
# 0    4953
# Name: count, dtype: int64

# %%
X_resampled.head()
# Out:
#      age  sex  steroid  antivirals  fatigue  malaise  anorexia  liver_big  \
# 102   27    0        0           0        1        0         0          1
# 179   43    0        0           0        1        1         1          1
# 92    33    0        1           0        0        0         0          2
# 14    47    0        0           1        0        0         0          1
# 106   35    0        0           0        1        0         0          2
#
#      liver_firm  spleen_palpable  spiders  ascites  varices  bilirubin  \
# 102           1                0        0        0        0   2.400000
# 179           0                0        1        0        0   4.547882
# 92            2                0        0        0        0   1.000000
# 14            0                0        0        0        0   1.427517
# 106           2                1        1        1        0   1.500000
#
#      alk_phosphate        sgot   albumin    protime  histology
# 102     168.000000  227.000000  3.000000  66.000000          1
# 179     105.325397   54.270345  3.227035  63.398219          0
# 92      105.325397   60.000000  4.000000  62.280899          1
# 14      105.325397   60.000000  3.817266  62.280899          0
# 106     138.000000   58.000000  2.600000  62.280899          1

# %% [markdown]
# #### combine "X_resampled" and "y_resampled"

# %%
train_data = pd.concat([X_resampled, y_resampled], axis=1)

s = setup(data=train_data, target='class', session_id=123, normalize=True, index=False)
# Out:
# <style type="text/css">
# #T_f8e43_row8_col1, #T_f8e43_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f8e43">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8e43_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f8e43_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8e43_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f8e43_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f8e43_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_f8e43_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f8e43_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f8e43_row1_col1" class="data row1 col1" >class</td>
#     </tr>
#     <tr>
#       <th id="T_f8e43_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f8e43_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_f8e43_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_f8e43_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f8e43_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_f8e43_row3_col1" class="data row3 col1" >(417530, 20)</td>
#     </tr>
#     <tr>
#       <th id="T_f8e43_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f8e43_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_f8e43_row4_col1" class="data row4 col1" >(417530, 20)</td>
#     </tr>
#     <tr>
#       <th id="T_f8e43_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f8e43_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_f8e43_row5_col1" class="data row5 col1" >(292271, 20)</td>
#     </tr>
#     <tr>
#       <th id="T_f8e43_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f8e43_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_f8e43_row6_col1" class="data row6 col1" >(125259, 20)</td>
#     </tr>
#     <tr>
#       <th id="T_f8e43_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f8e43_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_f8e43_row7_col1" class="data row7 col1" >19</td>
#     </tr>
#     <tr>
#       <th id="T_f8e43_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f8e43_row8_col0" class="data row8 col0" >Preprocess</td>
#       <td id="T_f8e43_row8_col1" class="data row8 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f8e43_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f8e43_row9_col0" class="data row9 col0" >Imputation type</td>
#       <td id="T_f8e43_row9_col1" class="data row9 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f8e43_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f8e43_row10_col0" class="data row10 col0" >Numeric imputation</td>
#       <td id="T_f8e43_row10_col1" class="data row10 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f8e43_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f8e43_row11_col0" class="data row11 col0" >Categorical imputation</td>
#       <td id="T_f8e43_row11_col1" class="data row11 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_f8e43_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f8e43_row12_col0" class="data row12 col0" >Normalize</td>
#       <td id="T_f8e43_row12_col1" class="data row12 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f8e43_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f8e43_row13_col0" class="data row13 col0" >Normalize method</td>
#       <td id="T_f8e43_row13_col1" class="data row13 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_f8e43_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f8e43_row14_col0" class="data row14 col0" >Fold Generator</td>
#       <td id="T_f8e43_row14_col1" class="data row14 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_f8e43_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f8e43_row15_col0" class="data row15 col0" >Fold Number</td>
#       <td id="T_f8e43_row15_col1" class="data row15 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f8e43_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f8e43_row16_col0" class="data row16 col0" >CPU Jobs</td>
#       <td id="T_f8e43_row16_col1" class="data row16 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f8e43_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f8e43_row17_col0" class="data row17 col0" >Use GPU</td>
#       <td id="T_f8e43_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f8e43_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f8e43_row18_col0" class="data row18 col0" >Log Experiment</td>
#       <td id="T_f8e43_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f8e43_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f8e43_row19_col0" class="data row19 col0" >Experiment Name</td>
#       <td id="T_f8e43_row19_col1" class="data row19 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_f8e43_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_f8e43_row20_col0" class="data row20 col0" >USI</td>
#       <td id="T_f8e43_row20_col1" class="data row20 col1" >92b4</td>
#     </tr>
#   </tbody>
# </table>

# %%
compare_models()
# Out:
# <style type="text/css">
# #T_79d97 th {
#   text-align: left;
# }
# #T_79d97_row0_col0, #T_79d97_row1_col0, #T_79d97_row2_col0, #T_79d97_row3_col0, #T_79d97_row4_col0, #T_79d97_row5_col0, #T_79d97_row6_col0, #T_79d97_row7_col0, #T_79d97_row7_col1, #T_79d97_row7_col2, #T_79d97_row7_col3, #T_79d97_row7_col4, #T_79d97_row7_col5, #T_79d97_row7_col6, #T_79d97_row7_col7, #T_79d97_row8_col0, #T_79d97_row8_col1, #T_79d97_row8_col2, #T_79d97_row8_col3, #T_79d97_row8_col4, #T_79d97_row8_col5, #T_79d97_row8_col6, #T_79d97_row8_col7, #T_79d97_row9_col0, #T_79d97_row9_col1, #T_79d97_row9_col2, #T_79d97_row9_col3, #T_79d97_row9_col4, #T_79d97_row9_col5, #T_79d97_row9_col6, #T_79d97_row9_col7, #T_79d97_row10_col0, #T_79d97_row10_col1, #T_79d97_row10_col2, #T_79d97_row10_col3, #T_79d97_row10_col4, #T